# %% [markdown]
# # FACILITY LOCATION PROBLEM
# ## (`Uncapacitated` and `Capacitated` models)
# Prepared by Bonn Kleiford 'Bikey' Seranilla

# %% [markdown]
# ### NOTES:
# - To start, make sure a `Customers.csv` and `Facilities.csv` files are added (see examples);
# - Random generator for randomly generated can be accessed thru function `random_generator`;
# - The FLP model can be either `uncapacitated` or `capacitated`;
# - Activated necessary arguments of thr function `MIP_model`;
# - For `capacitated` FLP, in order to avoid `infeasibility`, make sure Total CAPACITY >= Total DEMAND;
# - Additional constraint can be activated to delete a candidate facility by including Facility number (see `FACILITIES` dataframe);

# %% [markdown]
# ### Package installation

# %%
#Python packages
from math import sqrt
import gurobipy as gp
from gurobipy import GRB
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
from itertools import product
import networkx as nx
import networkx.generators.small as gs
import matplotlib.pyplot as plt
import plotly.express as px
import geopandas as gpd
from numpy.random import randint, binomial, uniform
import string
import random
import plotly.graph_objects as go
import panel as pn

# %%
pn.extension('plotly')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
grid = pn.GridSpec(sizing_mode='stretch_both')

# %% [markdown]
# ### Parameters (changeable) - CSV upload

# %%
#Read from CSV files
FACILITIES = pd.read_csv("./Facilities.csv")
CUSTOMERS = pd.read_csv("./Customers.csv")

#Parameter setting
customers = CUSTOMERS.set_index('Customer').drop(columns=['demand']).T.to_dict('list')
facilities = FACILITIES.set_index('Facility').drop(columns=['opening_cost', 'capacity', 'cost_per_km']).T.to_dict('list')
opening_cost = FACILITIES['opening_cost'].to_list()
cost_per_km = FACILITIES['cost_per_km'].dropna()[0]
demand = CUSTOMERS['demand'].to_list()
capacity = FACILITIES['capacity'].to_list()

# %%
pane_facilities = pn.panel(FACILITIES)
grid[0, 0] = pane_facilities
pane_facilities.servable()
# Out:
# DataFrame(DataFrame)

# %% [markdown]
# ##### ###DO NOT RUN IF CSVs ARE PROVIDED
# ##### JUST A SAMPLE (randomly generated)

# %%
########## JUST A SAMPLE (randomly generated) ############
def random_generator(num_facilities, num_customers, cost_per_km,
                     demand_min=10, demand_max=50, 
                     open_cost_min=10000, open_cost_max=30000):
    # num_facilities = 10
    # num_customers = 5
    # cost_per_km = 10

    #Random generator
    facilities = {}
    customers = {}
    f_names = list(string.ascii_letters)
    for n in range(num_facilities):
        f_names = f_names + ["%d_"%n + i for i in list(string.ascii_letters)]
    for i in range(num_facilities):
        facilities[f_names[i]] = ((uniform(-180, 179), uniform(-90, 89)))
    for i in range(num_customers):
        customers[i+1] = (uniform(-180, 179), uniform(-90, 89))

    demand = np.random.randint(demand_min,demand_max, size=(num_customers))
    opening_cost = [uniform(open_cost_min, open_cost_max) for i in range(num_facilities)]
    
    return num_facilities, num_customers, cost_per_km, demand_min, demand_max, open_cost_min, open_cost_max

if FACILITIES is None:
    num_facilities, num_customers, cost_per_km, demand_min, demand_max, open_cost_min, open_cost_max = random_generator(10, 5, 10)

# %% [markdown]
# ### Functions and computation (fixed)

# %%
# Compute key parameters of MIP model formulation
FACILITIES = pd.DataFrame.from_dict(facilities, orient='index', columns =['x_fac', 'y_fac'])
CUSTOMERS = pd.DataFrame.from_dict(customers, orient='index', columns =['x_cus', 'y_cus'])
lon_fac = FACILITIES.x_fac
lat_fac = FACILITIES.y_fac
lon_cus = CUSTOMERS.x_cus
lat_cus = CUSTOMERS.y_cus

num_facilities = len(FACILITIES)
num_customers = len(CUSTOMERS)
CF = list(product(range(num_customers), range(num_facilities))) #cartesian product for indexing

#Lists for dictionaries for plotting
fac_key_list=list(facilities.keys())
fac_val_list=list(facilities.values())
cus_key_list=list(customers.keys())
cus_val_list=list(customers.values())

# Compute distance between facility and customer
## This function determines the Euclidean distance between a facility and customer sites.
def distance_computation(location_1, location_2):
    d_x = location_1[0] - location_2[0]
    d_y = location_1[1] - location_2[1]
    return sqrt(d_x*d_x + d_y*d_y)
DISTANCE = np.array([distance_computation(list(customers.values())[c], list(facilities.values())[f]) for c, f in CF]).reshape(num_customers,num_facilities)

# %% [markdown]
# ## MIP Model

# %%
# MIP  model formulation
def check_status(status):
    if status == GRB.OPTIMAL:
        return
    elif status == GRB.INF_OR_UNBD:
        raise RuntimeError('Model is infeasible or unbounded')
    elif status == GRB.INFEASIBLE:
        raise RuntimeError('Model is infeasible')
    elif status == GRB.UNBOUNDED:
        raise RuntimeError('Model is unbounded')
    else:
        raise RuntimeError('Optimization ended with status %s' % status)
        
def MIP_model(with_capacity=None, delete_facility=None, delete_facility_2=None, delete_facility_3=None):
    m = gp.Model('Facility Location Problem (Demand Satisfaction)')
    m.Params.LogToConsole = 0
    
    #Decision Variables
    y = m.addVars(num_facilities, vtype=GRB.BINARY, name='Select')
    x = m.addVars(CF, vtype=GRB.CONTINUOUS, name='Assign')

    #Constraints        
    m.addConstrs((x[(c,f)] <= demand[c]*y[f] for c in range(num_customers) for f in range(num_facilities)),
                 name='Serve if open')
    m.addConstrs((gp.quicksum(x[(c,f)] for f in range(num_facilities)) == demand[c] for c in range(num_customers)),
                 name='Demand satisfaction')
    
    if with_capacity==1:
        m.addConstrs((gp.quicksum(x[(c,f)] for c in range(num_customers)) <= capacity[f]*y[f] for f in range(num_facilities)),
             name='Capacity satisfaction')
    
    if delete_facility is not None:
        m.addConstr(y[delete_facility] == 0, name='Remove a candidate facility')
    if delete_facility_2 is not None:
        m.addConstr(y[delete_facility_2] == 0, name='Remove another candidate facility')
    if delete_facility_3 is not None:
        m.addConstr(y[delete_facility_3] == 0, name='Remove a 3rd candidate facility')

    #Objective Function
    m.setObjective(gp.quicksum(y[i]*opening_cost[i] for i in range(num_facilities))
                   + gp.quicksum(x[(c,f)]*DISTANCE[c][f]*cost_per_km for f in range(num_facilities) for c in range(num_customers)), GRB.MINIMIZE)
    
    # check_status(m.status)
    m.optimize()
    
    ## Solution for y[f]
    open_facilities = np.zeros(num_facilities)
    for facility in y.keys():
        if (abs(y[facility].x) > 1e-6):
            open_facilities[facility] = y[facility].x
        else:
            open_facilities[facility] = 0
    
    ## Solution for x[c,f]
    cost_fac = np.zeros((num_customers, num_facilities))
    shipments = np.zeros((num_customers, num_facilities))
    for c, f in x.keys():
        if (abs(x[c, f].x) > 1e-6):
            shipments[c,f] = x[c, f].x
            cost_fac[c,f] = 1
        else:
            shipments[c,f] = 0
            cost_fac[c,f] = 0
    
    return m.ObjVal, open_facilities, shipments, cost_fac

ObjVal, open_facilities, shipments, cost_fac = MIP_model()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-06-19

# %% [markdown]
# ## Solution Report

# %% [markdown]
# #### Plotly stacked barchart of chosen facilities

# %%
df = pd.DataFrame(shipments, columns=fac_key_list)
fig = px.bar(df.T.rename_axis('Facilities'), barmode='stack', title="Customers served by facilities")
grid[0, 1:4] = pn.panel(fig)

# %% [markdown]
# #### Heatmap of opened facilities

# %%
fig = plt.figure(figsize=(12,3))
sns.set_style("whitegrid")
ax = sns.heatmap(shipments, linewidth=0.5, xticklabels=1, yticklabels=1, cmap="Purples")
plt.xticks(np.arange(num_facilities), labels=fac_key_list)
plt.xlabel("Facilities", fontsize = 20)
plt.ylabel("Customers", fontsize = 20) 
grid[1, 1:4] = pn.panel(fig)

# %% [markdown]
# ### Cost analysis

# %%
np.seterr('ignore')
shipments_cost = shipments*DISTANCE*cost_per_km
opencost_percus = np.where(np.isnan((cost_fac*opening_cost)/sum(cost_fac)), 0, (cost_fac*opening_cost)/sum(cost_fac))
cost_per_customer = (opencost_percus+shipments_cost)

# %%
import plotly.express as px
df_total = pd.DataFrame(cost_per_customer)
fig = px.bar(df_total.rename_axis('Customers').set_axis(fac_key_list, axis=1), title="Overall cost per customer (facility opening + transport costs)")
print('\n Total cost of operation is $', ObjVal)
grid[2, 1:4] = pn.panel(fig)
# Out:
#  Total cost of operation is $ 534.1727487990546

# %%
import plotly.express as px
df_facility = pd.DataFrame(opencost_percus)
fig = px.bar(df_facility.rename_axis('Customers').set_axis(fac_key_list, axis=1), title="Facility cost per customer (facility opening cost)")
grid[3, 1:4] = pn.panel(fig)

# %%
import plotly.express as px
df_transport = pd.DataFrame(shipments_cost)
fig = px.bar(df_transport.rename_axis('Customers').set_axis(fac_key_list, axis=1), title="Shipment cost per customer (transport cost)")
grid[4, 1:4] = pn.panel(fig)

# %% [markdown]
# ### Plotting with long-lat coordinates

# %%
## Aall customers and candidate facilities
fig = go.Figure(go.Scattergeo(
    mode = "markers",
    lon = FACILITIES['x_fac'],
    lat = FACILITIES['y_fac'],
    marker = {'size': 10},
    name = 'Facility'))

fig.add_trace(go.Scattergeo(
    mode = "markers",
    lon = CUSTOMERS['x_cus'],
    lat = CUSTOMERS['y_cus'],
    marker = {'size': 10},
    name = 'Customer'))


fig.update_layout(
    margin ={'l':0,'t':0,'b':0,'r':0},
    mapbox = {
        'center': {'lon': 0, 'lat': 0},
        'style': "stamen-terrain",
        'center': {'lon': -20, 'lat': -20},
        'zoom': 0.75})

grid[5, :4] = pn.panel(fig)

# %%
len(shipments)
# Out:
# 20

# %%
for c in range(len(shipments)):
    for f in range(len(shipments[0])):
        if (abs(shipments[c][f]) > 1e-6):
            fig.add_trace(go.Scattergeo(
            mode = "markers+lines",
            lon = [FACILITIES.iloc[f][0], CUSTOMERS.iloc[c][0]],
            lat = [FACILITIES.iloc[f][1], CUSTOMERS.iloc[c][1]],
            marker = {'size': 10},
            name = "F-{0} to C-{1}".format(fac_key_list[f],cus_key_list[c])))
            
fig.update_layout(
    margin ={'l':0,'t':0,'b':0,'r':0},
    mapbox = {
        'center': {'lon': 0, 'lat': 0},
        'style': "stamen-terrain",
        'center': {'lon': -20, 'lat': -20},
        'zoom': 0.75}),
    
grid[6, :4] = pn.panel(fig)

# %% [markdown]
# ### Plotting

# %%
#Creating a graph
G = nx.Graph()

#Adding nodes / vertices
for i in range(len(fac_key_list)):
  G.add_node(fac_key_list[i])
for i in range(len(cus_key_list)):
  G.add_node(cus_key_list[i])

#Adding links / edges
for c in range(len(shipments)):
    for f in range(len(shipments[0])):
        if (abs(shipments[c][f]) > 1e-6):
            G.add_edge(cus_key_list[c], fac_key_list[f])

#Graph colors
color_map = []
for node in G:
    if node in fac_key_list:
        color_map.append('purple')
    else: 
        color_map.append('white')  

#Network specifications
positions = dict(list(facilities.items()) + list(customers.items()))
options = {
    "node_color":color_map,
    "font_size": 2,
    "node_size": 100,
    "edgecolors": "black",
    "linewidths": 3,
    "width": 2}

#Plotting
plt.figure(figsize=(15,8))
nx.draw_networkx(G, positions, **options)
ax = plt.gca()
ax.margins(0.10)
plt.axis("on")
plt.grid(linewidth=0.5)
plt.show()

# %% [markdown]
# #### If we want to remove isolated / un-selected / un-opened facilities

# %%
G.remove_nodes_from(list(nx.isolates(G)))

#Graph colors
color_map = []
for node in G:
    if node in fac_key_list:
        color_map.append('purple')
    else: 
        color_map.append('white')  

#Network specifications
positions = dict(list(facilities.items()) + list(customers.items()))
options = {
    "node_color":color_map,
    "font_size": 2,
    "node_size": 100,
    "edgecolors": "black",
    "linewidths": 3,
    "width": 2}

#Plotting
plt.figure(figsize=(15,8))
nx.draw_networkx(G, positions, **options)
ax = plt.gca()
ax.margins(0.10)
plt.axis("on")
plt.grid(linewidth=0.5)
plt.show()

# %% [markdown]
# ### Printed solution

# %%
# display optimal values of decision variables
for f in range(len(open_facilities)):
    if (abs(open_facilities[f]) > 1e-6):
        print(f"Build a warehouse at location {f + 1}.")

# Shipments from facilities to customers.
for c in range(len(shipments)):
    for f in range(len(shipments[0])):
        if (abs(shipments[c][f]) > 1e-6):
            print(f"Customer {c + 1} receives {shipments[c][f]} or {round(100*shipments[c][f]/demand[c],2)}% of its demand from Warehouse {f + 1} .")
            # print(f"\n Warehouse {f + 1} delivers {100*(round(x[c, f].x)/demand[c])}% units of customer {c + 1}'s demand.")
# Out:
# Build a warehouse at location 2.
# Build a warehouse at location 3.
# Build a warehouse at location 4.
# Build a warehouse at location 5.
# Build a warehouse at location 6.
# Build a warehouse at location 7.
# Build a warehouse at location 8.
# Build a warehouse at location 9.
# Customer 1 receives 13.0 or 100.0% of its demand from Warehouse 3 .
# Customer 2 receives 7.0 or 100.0% of its demand from Warehouse 3 .
# Customer 3 receives 13.0 or 100.0% of its demand from Warehouse 4 .
# Customer 4 receives 2.0 or 100.0% of its demand from Warehouse 7 .
# Customer 5 receives 2.0 or 100.0% of its demand from Warehouse 3 .
# Customer 6 receives 4.0 or 100.0% of its demand from Warehouse 8 .
# Customer 7 receives 13.0 or 100.0% of its demand from Warehouse 8 .
# Customer 8 receives 6.0 or 100.0% of its demand from Warehouse 7 .
# Customer 9 receives 14.0 or 100.0% of its demand from Warehouse 4 .
# Customer 10 receives 12.0 or 100.0% of its demand from Warehouse 7 .
# ...

# %%
grid
# Out:
# GridSpec(ncols=4, nrows=7, sizing_mode='stretch_both')
#     [0] DataFrame(DataFrame, sizing_mode='stretch_both')
#     [1] Plotly(Figure, sizing_mode='stretch_both')
#     [2] Matplotlib(Figure, height=216, sizing_mode='stretch_both', width=864)
#     [3] Plotly(Figure, sizing_mode='stretch_both')
#     [4] Plotly(Figure, sizing_mode='stretch_both')
#     [5] Plotly(Figure, sizing_mode='stretch_both')
#     [6] Plotly(Figure, sizing_mode='stretch_both')
#     [7] Plotly(Figure, sizing_mode='stretch_both')
